# %% [markdown]
# # Data Exploratory Analysis

# %%
# Dependencies
import pandas as pd
from collections import Counter

# %%
movie_df=pd.read_csv('resources/cleaned_data.csv')
movie_df.head(5)
# Out:
#                          title  rated    released  runtime           director  \
# 0                    Inception  PG-13  2010-07-16      148  Christopher Nolan
# 1                   Iron Man 2  PG-13  2010-05-07      124        Jon Favreau
# 2               Shutter Island      R  2010-02-19      138    Martin Scorsese
# 3  Scott Pilgrim vs. the World  PG-13  2010-08-13      112       Edgar Wright
# 4                    Grown Ups  PG-13  2010-06-25      102       Dennis Dugan
#
#                                              writer  \
# 0                                 Christopher Nolan
# 1                Justin Theroux, Stan Lee, Don Heck
# 2                   Laeta Kalogridis, Dennis Lehane
# 3  Michael Bacall, Edgar Wright, Bryan Lee O'Malley
# 4                           Adam Sandler, Fred Wolf
#
#                                               actors  \
# 0  Leonardo DiCaprio, Joseph Gordon-Levitt, Ellio...
# 1  Robert Downey Jr., Mickey Rourke, Gwyneth Paltrow
# 2    Leonardo DiCaprio, Emily Mortimer, Mark Ruffalo
# 3  Michael Cera, Mary Elizabeth Winstead, Kieran ...
# 4             Adam Sandler, Salma Hayek, Kevin James
#
#                                                 plot  \
# 0  A thief who steals corporate secrets through t...
# 1  With the world now aware of his identity as Ir...
# 2  In 1954, a U.S. Marshal investigates the disap...
# 3  In a magically realistic version of Toronto, a...
# 4  After their high school basketball coach passe...
#
#                     language                                       country  \
# 0  English, Japanese, French                 United Kingdom, United States
# 1   English, French, Russian                                 United States
# 2            English, German                                 United States
# 3                    English  United States, United Kingdom, Canada, Japan
# 4           English, Spanish                                 United States
#
#    ...    boxoffice  response    genre               star       budget  \
# 0  ...  292576195.0      True   Action  Leonardo DiCaprio  160000000.0
# 1  ...  312433331.0      True   Action  Robert Downey Jr.  200000000.0
# 2  ...  128012934.0      True  Mystery  Leonardo DiCaprio   80000000.0
# 3  ...   32777690.0      True   Action       Michael Cera   60000000.0
# 4  ...  162001186.0      True   Comedy       Adam Sandler   80000000.0
#
#          gross  year internet_movie_database_rating rotten_tomato_rating  \
# 0  836836967.0  2010                            8.8                 87.0
# 1  623933331.0  2010                            7.0                 72.0
# 2  294805697.0  2010                            8.2                 68.0
# 3   48917974.0  2010                            7.5                 82.0
# 4  271457301.0  2010                            6.0                 11.0
#
#    metacritic_rating
# 0               74.0
# 1               57.0
# 2               63.0
# 3               69.0
# 4               30.0
#
# [5 rows x 25 columns]

# %%
movie_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1774 entries, 0 to 1773
# Data columns (total 25 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   title                           1774 non-null   object
#  1   rated                           1753 non-null   object
#  2   released                        1774 non-null   object
#  3   runtime                         1774 non-null   int64
#  4   director                        1766 non-null   object
#  5   writer                          1771 non-null   object
#  6   actors                          1774 non-null   object
#  7   plot                            1774 non-null   object
#  8   language                        1771 non-null   object
#  9   country                         1773 non-null   object
#  10  awards                          1654 non-null   object
#  11  metascore                       1774 non-null   float64
#  12  imdbrating                      1774 non-null   float64
#  13  imdbvotes                       1774 non-null   int64
#  14  dvd                             1736 non-null   object
#  15  boxoffice                       1774 non-null   float64
#  16  response                        1774 non-null   bool
#  17  genre                           1774 non-null   object
#  18  star                            1774 non-null   object
#  19  budget                          1774 non-null   float64
#  20  gross                           1774 non-null   float64
#  21  year                            1774 non-null   int64
#  22  internet_movie_database_rating  1774 non-null   float64
#  23  rotten_tomato_rating            1774 non-null   float64
#  24  metacritic_rating               1774 non-null   float64
# dtypes: bool(1), float64(8), int64(3), object(13)
# memory usage: 334.5+ KB

# %%
#Searching for most used words in title and plot
# %matplotlib inline
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
from IPython.display import Image, HTML

title_corpus = ' '.join(movie_df['title'])
plot_corpus = ' '.join(movie_df['plot'])

# %%
# plotting wordclod for title

title_wordcloud = WordCloud(stopwords=STOPWORDS, background_color='white', height=2000, width=4000).generate(title_corpus)
plt.figure(figsize=(16,8))
plt.imshow(title_wordcloud)
plt.axis('off')
plt.show()

# %%
#plotting word cloud fot movie plots

plot_wordcloud = WordCloud(stopwords=STOPWORDS, background_color='white', height=2000, width=4000).generate(plot_corpus)
plt.figure(figsize=(16,8))
plt.imshow(plot_wordcloud)
plt.axis('off')
plt.show()

# %% [markdown]
# #### Countries with most production

# %%
countries=movie_df['country'].to_list()

# %%
country_list=[]

for x in countries:
    
        country_array = str(x).split(',')
        for y in country_array:
            y=y.strip()
            country_list.append(y)

# %%
countries_most_production=pd.DataFrame(Counter(country_list).most_common(10))
countries_most_production.columns=['Country','Count']
countries_most_production
# Out:
#           Country  Count
# 0   United States   1485
# 1  United Kingdom    380
# 2          France    191
# 3          Canada    184
# 4           China     93
# 5         Germany     89
# 6       Australia     65
# 7           Japan     63
# 8           India     56
# 9           Spain     47

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(12,5))
sns.barplot(x='Country', y='Count', data=countries_most_production.iloc[1:10])
plt.show()

# %% [markdown]
# #### most used languages

# %%
languages=movie_df['language'].to_list()

# %%
language_list=[]

for x in languages:
    
        language_array = str(x).split(',')
        for y in language_array:
            y=y.strip()
            language_list.append(y)

# %%
most_used_languages= pd.DataFrame(Counter(language_list).most_common(10))
most_used_languages.columns=['Laguage','Count']
most_used_languages
# Out:
#     Laguage  Count
# 0   English   1677
# 1   Spanish    222
# 2    French    208
# 3    German    132
# 4   Russian    107
# 5   Italian     84
# 6  Japanese     78
# 7  Mandarin     56
# 8     Hindi     55
# 9    Arabic     48

# %%
plt.figure(figsize=(12,5))
sns.barplot(x='Laguage', y='Count', data=most_used_languages.iloc[1:10])
plt.show()

# %% [markdown]
# ### Checking Distribution of imdbrating

# %%
movie_df['imdbrating'].describe()
# Out:
# count    1774.000000
# mean        6.535457
# std         0.883080
# min         2.200000
# 25%         6.000000
# 50%         6.600000
# 75%         7.200000
# max         8.800000
# Name: imdbrating, dtype: float64

# %%
sns.distplot(movie_df['imdbrating'])
# Out:
# /opt/anaconda3/envs/ucsdvevn/lib/python3.6/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### Searching more corelated columns with imdb rating

# %%
score_df= movie_df[['imdbvotes','boxoffice','budget','gross','metascore','imdbrating','internet_movie_database_rating','rotten_tomato_rating','metacritic_rating']]

corr = score_df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_f79cba0c_848c_11ec_85c6_8c8590d01b2arow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f79cba0c_848c_11ec_85c6_8c8590d01b2arow0_col1 {
#             background-color:  #f5c4ac;
#             color:  #000000;
#         }    #T_f79cba0c_848c_11ec_85c6_8c8590d01b2arow0_col2 {
#             background-color:  #e9d5cb;
#             color:  #000000;
#         }    #T_f79cba0c_848c_11ec_85c6_8c8590d01b2arow0_col3 {
#             background-color:  #f0cdbb;
#             color:  #000000;
#         }    #T_f79cba0c_848c_11ec_85c6_8c8590d01b2arow0_col4 {
#             background-color:  #93b5fe;
#             color:  #000000;
#         }    #T_f79cba0c_848c_11ec_85c6_8c8590d01b2arow0_col5 {
#             background-color:  #bfd3f6;
#             color:  #000000;
#         }    #T_f79cba0c_848c_11ec_85c6_8c8590d01b2arow0_col6 {
#             background-color:  #bfd3f6;
#             color:  #000000;
#         }    #T_f79cba0c_848c_11ec_85c6_8c8590d01b2arow0_col7 {
#             background-color:  #98b9ff;
#             color:  #000000;
#         }    #T_f79cba0c_848c_11ec_85c6_8c8590d01b2arow0_col8 {
#             background-color:  #93b5fe;
#             color:  #000000;
#         }    #T_f79cba0c_848c_11ec_85c6_8c8590d01b2arow1_col0 {
#             background-color:  #ead5c9;
#             color:  #000000;
#         }    #T_f79cba0c_848c_11ec_85c6_8c8590d01b2arow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f79cba0c_848c_11ec_85c6_8c8590d01b2arow1_col2 {
#             background-color:  #f6a586;
#             color:  #000000;
#         }    #T_f79cba0c_848c_11ec_85c6_8c8590d01b2arow1_col3 {
#             background-color:  #d75445;
#             color:  #000000;
#         }    #T_f79cba0c_848c_11ec_85c6_8c8590d01b2arow1_col4 {
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }    #T_f79cba0c_848c_11ec_85c6_8c8590d01b2arow1_col5 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_f79cba0c_848c_11ec_85c6_8c8590d01b2arow1_col6 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_f79cba0c_848c_11ec_85c6_8c8590d01b2arow1_col7 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_f79cba0c_848c_11ec_85c6_8c8590d01b2arow1_col8 {
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }    #T_f79cba0c_848c_11ec_85c6_8c8590d01b2arow2_col0 {
#             background-color:  #b6cefa;
#             color:  #000000;
#         }    #T_f79cba0c_848c_11ec_85c6_8c8590d01b2arow2_col1 {
#             background-color:  #f7b599;
#             color:  #000000;
#         }    #T_f79cba0c_848c_11ec_85c6_8c8590d01b2arow2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f79cba0c_848c_11ec_85c6_8c8590d01b2arow2_col3 {
#             background-color:  #f4987a;
#             color:  #000000;
#         }    #T_f79cba0c_848c_11ec_85c6_8c8590d01b2arow2_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f79cba0c_848c_11ec_85c6_8c8590d01b2arow2_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f79cba0c_848c_11ec_85c6_8c8590d01b2arow2_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f79cba0c_848c_11ec_85c6_8c8590d01b2arow2_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f79cba0c_848c_11ec_85c6_8c8590d01b2arow2_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f79cba0c_848c_11ec_85c6_8c8590d01b2arow3_col0 {
#             background-color:  #dcdddd;
#             color:  #000000;
#         }    #T_f79cba0c_848c_11ec_85c6_8c8590d01b2arow3_col1 {
#             background-color:  #d75445;
#             color:  #000000;
#         }    #T_f79cba0c_848c_11ec_85c6_8c8590d01b2arow3_col2 {
#             background-color:  #f08b6e;
#             color:  #000000;
#         }    #T_f79cba0c_848c_11ec_85c6_8c8590d01b2arow3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f79cba0c_848c_11ec_85c6_8c8590d01b2arow3_col4 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_f79cba0c_848c_11ec_85c6_8c8590d01b2arow3_col5 {
#             background-color:  #6282ea;
#             color:  #000000;
#         }    #T_f79cba0c_848c_11ec_85c6_8c8590d01b2arow3_col6 {
#             background-color:  #6282ea;
#             color:  #000000;
#         }    #T_f79cba0c_848c_11ec_85c6_8c8590d01b2arow3_col7 {
#             background-color:  #6282ea;
#             color:  #000000;
#         }    #T_f79cba0c_848c_11ec_85c6_8c8590d01b2arow3_col8 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_f79cba0c_848c_11ec_85c6_8c8590d01b2arow4_col0 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }    #T_f79cba0c_848c_11ec_85c6_8c8590d01b2arow4_col1 {
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }    #T_f79cba0c_848c_11ec_85c6_8c8590d01b2arow4_col2 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_f79cba0c_848c_11ec_85c6_8c8590d01b2arow4_col3 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_f79cba0c_848c_11ec_85c6_8c8590d01b2arow4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f79cba0c_848c_11ec_85c6_8c8590d01b2arow4_col5 {
#             background-color:  #dcdddd;
#             color:  #000000;
#         }    #T_f79cba0c_848c_11ec_85c6_8c8590d01b2arow4_col6 {
#             background-color:  #dcdddd;
#             color:  #000000;
#         }    #T_f79cba0c_848c_11ec_85c6_8c8590d01b2arow4_col7 {
#             background-color:  #f08a6c;
#             color:  #000000;
#         }    #T_f79cba0c_848c_11ec_85c6_8c8590d01b2arow4_col8 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f79cba0c_848c_11ec_85c6_8c8590d01b2arow5_col0 {
#             background-color:  #85a8fc;
#             color:  #000000;
#         }    #T_f79cba0c_848c_11ec_85c6_8c8590d01b2arow5_col1 {
#             background-color:  #506bda;
#             color:  #000000;
#         }    #T_f79cba0c_848c_11ec_85c6_8c8590d01b2arow5_col2 {
#             background-color:  #5572df;
#             color:  #000000;
#         }    #T_f79cba0c_848c_11ec_85c6_8c8590d01b2arow5_col3 {
#             background-color:  #5572df;
#             color:  #000000;
#         }    #T_f79cba0c_848c_11ec_85c6_8c8590d01b2arow5_col4 {
#             background-color:  #e0dbd8;
#             color:  #000000;
#         }    #T_f79cba0c_848c_11ec_85c6_8c8590d01b2arow5_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f79cba0c_848c_11ec_85c6_8c8590d01b2arow5_col6 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f79cba0c_848c_11ec_85c6_8c8590d01b2arow5_col7 {
#             background-color:  #f7b99e;
#             color:  #000000;
#         }    #T_f79cba0c_848c_11ec_85c6_8c8590d01b2arow5_col8 {
#             background-color:  #e0dbd8;
#             color:  #000000;
#         }    #T_f79cba0c_848c_11ec_85c6_8c8590d01b2arow6_col0 {
#             background-color:  #85a8fc;
#             color:  #000000;
#         }    #T_f79cba0c_848c_11ec_85c6_8c8590d01b2arow6_col1 {
#             background-color:  #506bda;
#             color:  #000000;
#         }    #T_f79cba0c_848c_11ec_85c6_8c8590d01b2arow6_col2 {
#             background-color:  #5572df;
#             color:  #000000;
#         }    #T_f79cba0c_848c_11ec_85c6_8c8590d01b2arow6_col3 {
#             background-color:  #5572df;
#             color:  #000000;
#         }    #T_f79cba0c_848c_11ec_85c6_8c8590d01b2arow6_col4 {
#             background-color:  #e0dbd8;
#             color:  #000000;
#         }    #T_f79cba0c_848c_11ec_85c6_8c8590d01b2arow6_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;

# %% [markdown]
# ### Checking if there is any strong positive relation between imdb rating and imdb votes

# %%
imdb_feedback=movie_df[['imdbrating','imdbvotes']]

# %%
sns.jointplot(x='imdbrating', y='imdbvotes', data=imdb_feedback)

# %% [markdown]
# ### median budget in each genre

# %%
movie_df.groupby('genre')['budget'].median().nlargest(16)
# Out:
# genre
# Animation    75500000.0
# Action       46000000.0
# Romance      37600000.0
# Mystery      32000000.0
# Sci-Fi       27000000.0
# Adventure    25000000.0
# Biography    15000000.0
# Comedy       13500000.0
# Fantasy      12000000.0
# Crime        10000000.0
# Thriller      8000000.0
# Horror        5000000.0
# Drama         3500000.0
# Family              0.0
# Musical             0.0
# Sport               0.0
# Name: budget, dtype: float64

# %% [markdown]
# ### Median gross amout for each genre

# %%
movie_df.groupby('genre')['gross'].median().nlargest(16)
# Out:
# genre
# Animation    289319940.5
# Sci-Fi       161849455.0
# Mystery      135558194.0
# Action       108098767.5
# Adventure     83110217.0
# Romance       66834176.5
# Thriller      52425855.0
# Horror        39051010.0
# Fantasy       31595883.0
# Comedy        30642704.0
# Biography     24740061.0
# Drama         11122090.0
# Crime          9374932.0
# Musical        2595346.0
# Sport          1067629.0
# Family           20941.0
# Name: gross, dtype: float64

# %% [markdown]
# ### Median imdb votes in each genre

# %%
movie_df.groupby('genre')['imdbvotes'].median().nlargest(16)
# Out:
# genre
# Sci-Fi       552473.0
# Romance      317905.5
# Mystery      204982.0
# Action       129118.0
# Adventure     86522.0
# Animation     82333.5
# Fantasy       76053.0
# Comedy        59559.0
# Horror        56481.0
# Crime         55165.0
# Drama         47747.0
# Biography     47595.0
# Thriller      20261.0
# Sport           821.0
# Musical         595.0
# Family          185.0
# Name: imdbvotes, dtype: float64

# %% [markdown]
# ### Median runtime in each genre

# %%
movie_df.groupby('genre')['runtime'].median().nlargest(16)
# Out:
# genre
# Musical      145.0
# Mystery      117.0
# Biography    116.0
# Action       112.5
# Adventure    112.0
# Romance      111.0
# Crime        110.0
# Drama        109.0
# Sci-Fi       105.0
# Comedy       102.0
# Fantasy       99.5
# Animation     96.0
# Horror        95.0
# Sport         94.0
# Family        91.0
# Thriller      91.0
# Name: runtime, dtype: float64

# %% [markdown]
# ### Statistical tests
